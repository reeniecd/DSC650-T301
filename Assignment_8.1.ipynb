# %%
import json
import uuid

from kafka import KafkaProducer, KafkaAdminClient
from kafka.admin.new_topic import NewTopic
from kafka.errors import TopicAlreadyExistsError

import os
import pandas as pd
import datetime
import threading
from pathlib import Path
import time
import s3fs
import pyarrow.parquet as pq
from collections import namedtuple

# %%
config = dict(
    bootstrap_servers=['kafka.kafka.svc.cluster.local:9092'],
    first_name='Reenie',
    last_name='Christudass'
)

config['client_id'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)
config['topic_prefix'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)

print(config)
# Out:
# {'bootstrap_servers': ['kafka.kafka.svc.cluster.local:9092'], 'first_name': 'Reenie', 'last_name': 'Christudass', 'client_id': 'ChristudassReenie', 'topic_prefix': 'ChristudassReenie'}

# %%
def loadParquet(parq_path):
    pqr = spark.read.parquet(parq_path)
    # Convert from spark dataframe to pandas dataframe
    pqr = pqr.toPandas()
    return pqr

def splitstr(std):
    before, after = str(std).split('.')
    return before, after

def startTimer(results_dir):
    # Loop on time
    print("call function here")
    retval = startTimedParquetStreamUpdateLoop(results_dir)
    # Stop if time is over and there are no more partitions.
    if ((time.time() - start_time) < 70 and retval == 0):
        t = threading.Timer(interval, startTimer(results_dir))

# %%
def create_kafka_topic(topic_name, config=config, num_partitions=1, replication_factor=1):
    bootstrap_servers = config['bootstrap_servers']
    client_id = config['client_id']
    topic_prefix = config['topic_prefix']
    name = '{}-{}'.format(topic_prefix, topic_name)
    
    admin_client = KafkaAdminClient(
        bootstrap_servers=bootstrap_servers, 
        client_id=client_id
    )
    
    topic = NewTopic(
        name=name,
        num_partitions=num_partitions,
        replication_factor=replication_factor
    )

    topic_list = [topic]
    try:
        admin_client.create_topics(new_topics=topic_list)
        print('Created topic "{}"'.format(name))
    except TopicAlreadyExistsError as e:
        print('Topic "{}" already exists'.format(name))

# %%
    
create_kafka_topic('locations')
create_kafka_topic('accelerations')
# Out:
# Created topic "ChristudassReenie-locations"
# Created topic "ChristudassReenie-accelerations"

# %%
producer = KafkaProducer(
  bootstrap_servers=config['bootstrap_servers'],
  value_serializer=lambda x: json.dumps(x).encode('utf-8')
)

# %%
def on_send_success(record_metadata):
    print('Message sent:\n    Topic: "{}"\n    Partition: {}\n    Offset: {}'.format(
        record_metadata.topic,
        record_metadata.partition,
        record_metadata.offset
    ))
    
def on_send_error(excp):
    print('I am an errback', exc_info=excp)
    # handle exception

def send_data(topic, data, config=config, producer=producer, msg_key=None):
    topic_prefix = config['topic_prefix']
    topic_name = '{}-{}'.format(topic_prefix, topic)
    
    if msg_key is not None:
        key = msg_key
    else:
        key = uuid.uuid4().hex
    
    producer.send(
        topic_name, 
        value=data,
        key=key.encode('utf-8')
    ).add_callback(on_send_success).add_errback(on_send_error)

# %%
example_data = dict(
    key1='value1',
    key2='value2'
)

send_data('locations', example_data)
# Out:
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 0

# %%
import os
import pandas as pd
import pyarrow.parquet as pq

# Set the path to the directory containing the parquet files
path = "dsc650/data/processed/bdd/accelerations"

# Create an empty list to store the dataframes
dfs = []

# Loop through each subdirectory in the path
for subdir in os.listdir(path):
    subdir_path = os.path.join(path, subdir)
    # Loop through each parquet file in the subdirectory
    for file in os.listdir(subdir_path):
        if file.endswith(".parquet"):
            file_path = os.path.join(subdir_path, file)
            # Read the parquet file into a dataframe
            table = pq.read_table(file_path)
            df = table.to_pandas()
            # Append the dataframe to the list of dataframes
            dfs.append(df)

# Concatenate all the dataframes into one
df_acc = pd.concat(dfs, ignore_index=True)
df_acc['timestamp'] = df['timestamp'].astype(str)
# Print the dataframe
print(df_acc.head())
# Out:
#                                  id                           ride_id
# 0  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5  \
# 1  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5
# 2  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5
# 3  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5
# 4  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5
#
#                                uuid                   timestamp     offset
# 0  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:04.256854  17.912913  \
# 1  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:04.256854  17.932913
# 2  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:04.256854  17.951913
# 3  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:04.256854  17.971913
# 4  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:04.256854  17.990913
#
#        x      y      z  timelapse                                  filename
# 0 -1.044  0.091  0.153      False  d745b92f-aefd-467d-9121-7a71308e8d6d.mov
# 1 -1.009  0.065  0.121      False  d745b92f-aefd-467d-9121-7a71308e8d6d.mov
# 2 -0.978  0.087  0.150      False  d745b92f-aefd-467d-9121-7a71308e8d6d.mov
# 3 -0.998  0.086  0.134      False  d745b92f-aefd-467d-9121-7a71308e8d6d.mov
# 4 -0.980  0.099  0.186      False  d745b92f-aefd-467d-9121-7a71308e8d6d.mov

# %%
import os
import pandas as pd
import pyarrow.parquet as pq

# Set the path to the directory containing the parquet files
path = "dsc650/data/processed/bdd/locations"

# Create an empty list to store the dataframes
dfs = []

# Loop through each subdirectory in the path
for subdir in os.listdir(path):
    subdir_path = os.path.join(path, subdir)
    # Loop through each parquet file in the subdirectory
    for file in os.listdir(subdir_path):
        if file.endswith(".parquet"):
            file_path = os.path.join(subdir_path, file)
            # Read the parquet file into a dataframe
            table = pq.read_table(file_path)
            df = table.to_pandas()
            # Append the dataframe to the list of dataframes
            dfs.append(df)

# Concatenate all the dataframes into one
df_loc = pd.concat(dfs, ignore_index=True)
df_loc['timestamp'] = df['timestamp'].astype(str)
# Print the dataframe
print(df_loc.head())
# Out:
#                                  id                           ride_id
# 0  85c61911b7fe2ced1000c33c9e932706  6760ffa3f41908695d1405b776c3e8d5  \
# 1  58682c5d48cad9d9e103431d773615bf  c9a2b46c9aa515b632eddc45c4868482
# 2  759e4b98ce8cfadd1004453cb2107436  91126a54bb966b38f64c62aded306c37
# 3  d23ab293596c360dab6e8fcdb1160292  57ac74e28d873fb0b1c7d9998349f008
# 4  5f0b30f49da18ebc1b22e3f84a9a14db  01d87368140cb74ba7cead55b6dbfc7c
#
#                                uuid                   timestamp     offset
# 0  dad7eae44e784b549c8c5a3aa051a8c7  1970-01-01 00:25:04.256854  18.077913  \
# 1  19b9aa10588646b3bf22c9b4865a7995                         NaN  18.525061
# 2  2cc21cea5b534b59b596172f8dacbe5b                         NaN  85.620195
# 3  8c6d4a328f8f4d1abd748eaa64db26b3                         NaN  85.294091
# 4  b59f82a2612048079456e8b5f9d5fdb9                         NaN  85.385934
#
#        course   latitude  longitude       geohash  speed  accuracy  timelapse
# 0  153.281250  40.679180 -73.818664  dr5x2jqvkky2   5.34      10.0      False  \
# 1  299.619141  40.762750 -73.961671  dr5ruuwu0pks   4.04      10.0      False
# 2  261.366486  40.626220 -73.974052  dr5rhev8zskc   1.28      10.0      False
# 3  134.296875  40.611788 -73.924899  dr5rjc1sbczz  11.04      10.0      False
# 4   27.136377  40.709175 -74.012036  dr5reffh4s39   0.00      30.0      False
#
#                                    filename
# 0  d745b92f-aefd-467d-9121-7a71308e8d6d.mov
# 1  e2f795a7-6a7d-4500-b5d7-4569de996811.mov
# 2  891d1bd9-2ded-442c-8111-5f2692f3928c.mov
# 3  3e6093ea-22ec-47db-812c-47dec2b98d27.mov
# 4  a0c0bc84-748f-4e73-b772-861d16889edf.mov

# %%
start_time = time.time()
offset = []
topics = []
datas = []
for i in range(df_acc.shape[0]):
    data_acc = df_acc.loc[i].to_dict()
    offset.append(data_acc['offset'])
    datas.append(data_acc)
    topics.append('accelerations')
for i in range(df_loc.shape[0]):
    data_loc = df_loc.loc[i].to_dict()
    offset.append(data_loc['offset'])
    datas.append(data_loc)
    topics.append('locations')

# %%
#combining the lists into a dataframe and sorting by offset
df = pd.DataFrame({'offset': offset, 'topics': topics, 'datas': datas})
df = df.sort_values(by = ['offset'])
df.head()
# Out:
#          offset         topics
# 22800  0.822061  accelerations  \
# 22801  0.842061  accelerations
# 22802  0.862061  accelerations
# 22803  0.882061  accelerations
# 22804  0.902061  accelerations
#
#                                                    datas
# 22800  {'id': '58682c5d48cad9d9e103431d773615bf', 'ri...
# 22801  {'id': '58682c5d48cad9d9e103431d773615bf', 'ri...
# 22802  {'id': '58682c5d48cad9d9e103431d773615bf', 'ri...
# 22803  {'id': '58682c5d48cad9d9e103431d773615bf', 'ri...
# 22804  {'id': '58682c5d48cad9d9e103431d773615bf', 'ri...

# %%
for i in range(df.shape[0]):
    offset = df['offset'][i]
    while (time.time() - start_time) < offset:
        pass
    #print(df['topics'][i], df['datas'][i])
    send_data(df['topics'][i], df['datas'][i])
# Out:
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23512
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23513
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23514
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23515
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23516
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23517
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23518
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23519
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23520
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23521
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23522
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23523
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23524
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23525
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23526
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23527
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23528
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23529
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23530
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23531
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23532
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23533
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23534
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23535
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23536
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23537
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23538
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23539
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23540
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23541
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23542
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23543
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23544
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23545
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23546
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23547
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23548
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23549
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23550
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23551
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23552
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23553
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23554
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23555
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23556
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23557
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23558
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23559
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23560
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23561
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23562
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23563
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23564
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23565
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23566
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23567
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23568
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23569
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23570
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23571
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23572
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23573
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23574
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23575
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23576
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23577
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23578
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23579
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23580
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23581
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23582
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23583
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23584
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23585
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23586
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23587
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23588
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23589
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23590
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23591
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23592
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23593
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23594
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23595
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23596
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23597
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23598
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23599
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23600
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23601
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23602
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23603
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23604
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23605
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23606
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23607
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23608
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23609
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23610
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23611
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23612
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23613
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23614
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23615
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23616
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23617
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23618
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23619
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23620
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23621
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23622
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23623
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23624
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23625
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23626
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23627
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23628
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23629
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23630
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23631
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23632
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23633
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23634
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23635
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23636
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23637
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23638
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23639
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23640
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23641
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23642
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23643
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23644
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23645
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23646
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23647
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23648
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23649
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23650
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23651
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23652
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23653
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23654
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23655
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23656
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23657
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23658
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23659
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23660
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23661
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23662
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23663
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23664
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23665
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23666
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23667
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23668
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23669
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23670
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23671
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23672
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23673
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23674
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23675
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23676
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23677
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23678
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23679
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23680
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23681
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23682
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23683
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23684
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23685
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23686
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23687
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23688
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23689
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23690
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23691
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23692
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23693
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23694
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23695
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23696
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23697
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23698
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23699
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23700
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23701
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23702
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23703
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23704
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23705
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23706
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23707
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23708
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23709
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23710
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23711
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23712
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23713
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23714
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23715
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23716
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23717
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23718
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23719
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23720
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23721
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23722
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23723
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23724
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23725
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23726
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23727
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23728
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23729
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23730
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23731
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23732
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23733
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23734
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23735
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23736
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23737
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23738
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23739
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23740
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23741
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23742
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23743
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23744
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23745
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23746
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23747
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23748
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23749
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23750
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23751
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23752
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23753
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23754
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23755
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23756
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23757
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23758
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23759
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23760
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23761
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23762
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23763
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23764
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23765
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23766
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23767
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23768
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23769
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23770
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23771
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23772
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23773
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23774
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23775
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23776
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23777
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23778
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23779
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23780
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23781
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23782
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23783
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23784
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23785
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23786
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23787
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23788
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23789
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23790
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23791
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23792
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23793
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23794
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23795
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23796
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23797
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23798
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23799
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23800
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23801
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23802
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23803
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23804
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23805
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23806
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23807
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23808
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23809
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23810
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23811
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23812
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23813
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23814
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23815
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23816
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23817
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23818
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23819
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23820
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23821
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23822
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23823
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23824
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23825
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23826
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23827
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23828
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23829
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23830
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23831
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23832
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23833
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23834
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23835
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23836
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23837
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23838
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23839
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23840
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23841
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23842
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23843
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23844
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23845
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23846
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23847
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23848
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23849
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23850
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23851
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23852
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23853
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23854
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23855
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23856
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23857
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23858
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23859
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23860
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23861
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23862
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23863
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23864
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23865
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23866
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23867
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23868
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23869
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23870
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23871
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23872
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23873
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23874
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23875
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23876
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23877
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23878
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23879
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23880
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23881
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23882
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23883
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23884
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23885
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23886
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23887
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23888
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23889
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23890
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23891
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23892
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23893
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23894
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23895
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23896
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23897
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23898
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23899
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23900
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23901
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23902
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23903
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23904
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23905
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23906
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23907
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23908
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23909
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23910
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23911
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23912
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23913
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23914
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23915
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23916
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23917
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23918
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23919
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23920
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23921
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23922
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23923
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23924
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23925
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23926
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23927
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23928
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23929
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23930
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23931
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23932
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23933
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23934
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23935
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23936
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23937
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23938
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23939
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23940
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23941
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23942
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23943
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23944
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23945
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23946
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23947
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23948
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23949
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23950
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23951
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23952
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23953
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23954
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23955
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23956
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23957
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23958
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23959
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23960
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23961
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23962
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23963
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23964
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23965
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23966
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23967
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23968
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23969
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23970
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23971
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23972
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23973
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23974
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23975
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23976
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23977
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23978
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23979
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23980
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23981
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23982
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23983
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23984
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23985
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23986
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23987
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23988
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23989
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23990
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23991
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23992
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23993
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23994
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23995
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23996
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23997
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23998
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 23999
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24000
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24001
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24002
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24003
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24004
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24005
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24006
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24007
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24008
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24009
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24010
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24011
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24012
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24013
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24014
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24015
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24016
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24017
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24018
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24019
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24020
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
#     Partition: 0
#     Offset: 24021
# Message sent:
#     Topic: "ChristudassReenie-accelerations"
# ...
#     Partition: 0
#     Offset: 775
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 776
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 777
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 778
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 779
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 780
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 781
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 782
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 783
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 784
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 785
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 786
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 787
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 788
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 789
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 790
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 791
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 792
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 793
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 794
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 795
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 796
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 797
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 798
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 799
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 800
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 801
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 802
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 803
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 804
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 805
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 806
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 807
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 808
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 809
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 810
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 811
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 812
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 813
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 814
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 815
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 816
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 817
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 818
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 819
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 820
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 821
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 822
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 823
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 824
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 825
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 826
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 827
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 828
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 829
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 830
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 831
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 832
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 833
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 834
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 835
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 836
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 837
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 838
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 839
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 840
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 841
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 842
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 843
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 844
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 845
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 846
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 847
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 848
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 849
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 850
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 851
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 852
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 853
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 854
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 855
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 856
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 857
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 858
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 859
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 860
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 861
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 862
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 863
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 864
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 865
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 866
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 867
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 868
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 869
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 870
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 871
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 872
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 873
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 874
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 875
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 876
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 877
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 878
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 879
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 880
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 881
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 882
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 883
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 884
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 885
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 886
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 887
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 888
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 889
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 890
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 891
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 892
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 893
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 894
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 895
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 896
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 897
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 898
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 899
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 900
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 901
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 902
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 903
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 904
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 905
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 906
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 907
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 908
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 909
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 910
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 911
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 912
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 913
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 914
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 915
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 916
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 917
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 918
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 919
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 920
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 921
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 922
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 923
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 924
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 925
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 926
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 927
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 928
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 929
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 930
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 931
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 932
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 933
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 934
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 935
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 936
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 937
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 938
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 939
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 940
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 941
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 942
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 943
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 944
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 945
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 946
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 947
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 948
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 949
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 950
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 951
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 952
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 953
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 954
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 955
# Message sent:
#     Topic: "ChristudassReenie-locations"
#     Partition: 0
#     Offset: 956
